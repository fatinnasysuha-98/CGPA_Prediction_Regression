# %% [markdown]
# # Load Dependencies

# %%
#Load Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import pyplot
from pandas import read_csv
from pandas import set_option
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import Binarizer
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from pandas import read_csv
from sklearn.decomposition import PCA
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import ShuffleSplit
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

print("All dependencies import successfully")
# Out:
# All dependencies import successfully

# %%
df = pd.read_csv(r"C:\Users\Admin\Desktop\Career Development\Projects\CGPA Prediction Regression\mentalhealth_dataset.csv")
df
# Out:
#       Timestamp  Gender  Age           Course YearOfStudy  CGPA  Depression  \
# 0     13/7/2020  Female   24    Biotechnology      Year 3  2.38           1
# 1     13/7/2020  Female   18    Biotechnology      Year 3  4.00           0
# 2     13/7/2020  Female   25    Biotechnology      Year 3  3.68           0
# 3     13/7/2020  Female   18      Engineering      year 4  4.00           0
# 4     13/7/2020  Female   20      Engineering      year 4  2.00           1
# ..          ...     ...  ...              ...         ...   ...         ...
# 995  2023-07-09  Female   20              KOE      year 1  2.31           0
# 996  2023-07-09  Female   23      Engineering      year 1  3.72           1
# 997  2023-07-09  Female   19  Human Sciences       Year 2  2.00           0
# 998  2023-07-09  Female   24  Human Sciences       Year 2  3.89           1
# 999  2023-07-09  Female   20  Human Sciences       Year 2  2.46           1
#
#      Anxiety  PanicAttack  SpecialistTreatment  SymptomFrequency_Last7Days  \
# 0          0            0                    0                           5
# 1          1            0                    0                           0
# 2          0            1                    0                           3
# 3          0            0                    0                           3
# 4          1            0                    0                           0
# ..       ...          ...                  ...                         ...
# 995        1            0                    0                           6
# 996        0            0                    0                           3
# 997        0            1                    0                           1
# 998        0            1                    0                           5
# 999        0            0                    0                           0
#
#      HasMentalHealthSupport  SleepQuality  StudyStressLevel  \
# 0                         0             4                 5
# 1                         0             4                 4
# 2                         0             1                 2
# 3                         0             5                 1
# 4                         0             2                 4
# ..                      ...           ...               ...
# 995                       0             1                 3
# 996                       0             4                 1
# 997                       0             5                 4
# 998                       0             5                 4
# 999                       0             2                 5
#
#      StudyHoursPerWeek  AcademicEngagement
# 0                    8                   2
# 1                   13                   5
# 2                   13                   1
# 3                   19                   2
# 4                    3                   2
# ..                 ...                 ...
# 995                  7                   1
# 996                 12                   2
# 997                  3                   1
# 998                 13                   3
# 999                  8                   1
#
# [1000 rows x 16 columns]

# %% [markdown]
# # Inspecting Data

# %%
#To check how many rows and columns
df.shape
# Out:
# (1000, 16)

# %%
# DataFrames summary (column names, dtypes, non-null counts, memory usage)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Timestamp                   1000 non-null   object
#  1   Gender                      1000 non-null   object
#  2   Age                         1000 non-null   int64
#  3   Course                      1000 non-null   object
#  4   YearOfStudy                 1000 non-null   object
#  5   CGPA                        1000 non-null   float64
#  6   Depression                  1000 non-null   int64
#  7   Anxiety                     1000 non-null   int64
#  8   PanicAttack                 1000 non-null   int64
#  9   SpecialistTreatment         1000 non-null   int64
#  10  SymptomFrequency_Last7Days  1000 non-null   int64
#  11  HasMentalHealthSupport      1000 non-null   int64
#  12  SleepQuality                1000 non-null   int64
#  13  StudyStressLevel            1000 non-null   int64
#  14  StudyHoursPerWeek           1000 non-null   int64
#  15  AcademicEngagement          1000 non-null   int64
# dtypes: float64(1), int64(11), object(4)
# memory usage: 125.1+ KB

# %%
#To check data type of every columns
df.dtypes
# Out:
# Timestamp                      object
# Gender                         object
# Age                             int64
# Course                         object
# YearOfStudy                    object
# CGPA                          float64
# Depression                      int64
# Anxiety                         int64
# PanicAttack                     int64
# SpecialistTreatment             int64
# SymptomFrequency_Last7Days      int64
# HasMentalHealthSupport          int64
# SleepQuality                    int64
# StudyStressLevel                int64
# StudyHoursPerWeek               int64
# AcademicEngagement              int64
# dtype: object

# %%
#To check first 5 rows
df.head()
# Out:
#    Timestamp  Gender  Age         Course YearOfStudy  CGPA  Depression  \
# 0  13/7/2020  Female   24  Biotechnology      Year 3  2.38           1
# 1  13/7/2020  Female   18  Biotechnology      Year 3  4.00           0
# 2  13/7/2020  Female   25  Biotechnology      Year 3  3.68           0
# 3  13/7/2020  Female   18    Engineering      year 4  4.00           0
# 4  13/7/2020  Female   20    Engineering      year 4  2.00           1
#
#    Anxiety  PanicAttack  SpecialistTreatment  SymptomFrequency_Last7Days  \
# 0        0            0                    0                           5
# 1        1            0                    0                           0
# 2        0            1                    0                           3
# 3        0            0                    0                           3
# 4        1            0                    0                           0
#
#    HasMentalHealthSupport  SleepQuality  StudyStressLevel  StudyHoursPerWeek  \
# 0                       0             4                 5                  8
# 1                       0             4                 4                 13
# 2                       0             1                 2                 13
# 3                       0             5                 1                 19
# 4                       0             2                 4                  3
#
#    AcademicEngagement
# 0                   2
# 1                   5
# 2                   1
# 3                   2
# 4                   2

# %%
#To check last 5 rows
df.tail()
# Out:
#       Timestamp  Gender  Age           Course YearOfStudy  CGPA  Depression  \
# 995  2023-07-09  Female   20              KOE      year 1  2.31           0
# 996  2023-07-09  Female   23      Engineering      year 1  3.72           1
# 997  2023-07-09  Female   19  Human Sciences       Year 2  2.00           0
# 998  2023-07-09  Female   24  Human Sciences       Year 2  3.89           1
# 999  2023-07-09  Female   20  Human Sciences       Year 2  2.46           1
#
#      Anxiety  PanicAttack  SpecialistTreatment  SymptomFrequency_Last7Days  \
# 995        1            0                    0                           6
# 996        0            0                    0                           3
# 997        0            1                    0                           1
# 998        0            1                    0                           5
# 999        0            0                    0                           0
#
#      HasMentalHealthSupport  SleepQuality  StudyStressLevel  \
# 995                       0             1                 3
# 996                       0             4                 1
# 997                       0             5                 4
# 998                       0             5                 4
# 999                       0             2                 5
#
#      StudyHoursPerWeek  AcademicEngagement
# 995                  7                   1
# 996                 12                   2
# 997                  3                   1
# 998                 13                   3
# 999                  8                   1

# %% [markdown]
# # Uniques Values

# %%
#To loops through every column in the DataFrame and prints all the unique values in each one
for col in df.columns:
    print(f"Unique values in column '{col}': {df[col].unique()}")
# Out:
# Unique values in column 'Timestamp': ['13/7/2020' '18/7/2020' '2020-07-08' '2020-07-09' '13/7/2021' '18/7/2021'
#  '2021-07-08' '2021-07-09' '13/7/2022' '18/7/2022' '2022-07-08'
#  '2022-07-09' '13/7/2023' '18/7/2023' '2023-07-08' '2023-07-09']
# Unique values in column 'Gender': ['Female' 'Male']
# Unique values in column 'Age': [24 18 25 20 19 21 23 22]
# Unique values in column 'Course': ['Biotechnology' 'Engineering' 'Communication ' 'Diploma Nursing'
#  'Pendidikan Islam ' 'Radiography' 'psychology' 'Fiqh fatwa ' 'BIT'
#  'DIPLOMA TESL' 'Koe' 'KOE' 'BENL' 'Fiqh' 'Islamic Education' 'BCS'
#  'Nursing ' 'Pendidikan Islam' 'Biomedical science' 'Islamic education'
#  'Laws' 'Mathemathics' 'Pendidikan islam' 'Human Resources' 'Irkhs'
#  'Psychology' 'KENMS' 'Accounting ' 'ENM' 'Marine science'
#  'Banking Studies' 'Business Administration' 'Law' 'KIRKHS' 'Usuluddin '
#  'TAASL' 'Engine' 'koe' 'Kirkhs' 'CTS' 'engin' 'Econs' 'MHSC' 'Malcom'
#  'Kop' 'Human Sciences ' 'ALA' 'Benl' 'IT']
# Unique values in column 'YearOfStudy': ['Year 3' 'year 4' 'Year 2' 'year 2' 'year 1' 'Year 1' 'year 3']
# Unique values in column 'CGPA': [2.38 4.   3.68 2.   2.72 2.3  2.84 3.28 2.12 2.59 3.98 3.51 3.12 2.89
#  3.38 3.61 3.77 3.47 2.58 3.36 3.5  3.39 3.95 3.25 2.75 2.77 3.3  3.96
#  2.9  2.43 3.65 2.42 2.61 2.91 3.53 2.28 3.64 2.15 2.69 2.83 2.49 3.35
#  3.32 2.71 3.09 3.46 3.7  2.7  3.72 2.93 2.79 3.14 3.43 2.16 2.85 3.01
#  3.66 3.49 2.66 3.16 2.08 3.06 2.52 2.36 3.58 2.86 2.32 3.54 2.26 3.
#  3.34 2.45 3.67 3.71 3.83 3.87 2.41 2.13 2.94 2.63 3.04 2.82 2.39 3.97
#  3.03 2.74 3.37 2.23 2.99 2.76 3.18 3.27 3.63 3.45 2.09 2.18 2.04 2.05
#  3.22 2.64 2.53 3.24 2.06 3.6  2.31 3.44 3.11 2.65 3.73 3.74 3.81 2.14
#  2.47 3.86 3.08 2.88 3.91 3.21 3.75 2.19 3.69 2.03 3.94 3.56 2.34 2.8
#  3.31 3.62 2.29 2.21 2.87 2.54 2.68 3.4  3.29 3.85 3.05 2.25 2.56 2.98
#  3.13 2.97 2.55 2.73 2.78 3.55 3.92 2.22 2.2  3.48 3.57 2.96 2.27 2.1
#  2.17 2.4  2.33 3.84 2.81 3.59 3.88 3.15 3.8  3.76 3.26 3.23 2.35 3.93
#  2.37 3.42 3.17 2.95 3.79 2.07 2.51 3.19 3.9  3.1  3.07 2.67 3.89 2.46
#  2.57 2.24 2.11 3.82 3.99]
# Unique values in column 'Depression': [1 0]
# Unique values in column 'Anxiety': [0 1]
# Unique values in column 'PanicAttack': [0 1]
# Unique values in column 'SpecialistTreatment': [0 1]
# Unique values in column 'SymptomFrequency_Last7Days': [5 0 3 4 6 7 1 2]
# Unique values in column 'HasMentalHealthSupport': [0 1]
# Unique values in column 'SleepQuality': [4 1 5 2 3]
# Unique values in column 'StudyStressLevel': [5 4 2 1 3]
# Unique values in column 'StudyHoursPerWeek': [ 8 13 19  3 15  1  5 16  6 18 10 14  4  9 12  2  7 11 17]
# Unique values in column 'AcademicEngagement': [2 5 1 3 4]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Assign CGPA as Target Label

# %%
# Move 'cgpa' to the last column and delete its from the original position
# Extract 'cgpa' column and save it
cgpa_column = df.pop('CGPA')

#Creates a new column called 'CGPA' to the end of the DataFrame
df['CGPA'] = cgpa_column

#Verify the new column order
print(df.columns.tolist())
df
# Out:
# ['Timestamp', 'Gender', 'Age', 'Course', 'YearOfStudy', 'Depression', 'Anxiety', 'PanicAttack', 'SpecialistTreatment', 'SymptomFrequency_Last7Days', 'HasMentalHealthSupport', 'SleepQuality', 'StudyStressLevel', 'StudyHoursPerWeek', 'AcademicEngagement', 'CGPA']
#       Timestamp  Gender  Age           Course YearOfStudy  Depression  \
# 0     13/7/2020  Female   24    Biotechnology      Year 3           1
# 1     13/7/2020  Female   18    Biotechnology      Year 3           0
# 2     13/7/2020  Female   25    Biotechnology      Year 3           0
# 3     13/7/2020  Female   18      Engineering      year 4           0
# 4     13/7/2020  Female   20      Engineering      year 4           1
# ..          ...     ...  ...              ...         ...         ...
# 995  2023-07-09  Female   20              KOE      year 1           0
# 996  2023-07-09  Female   23      Engineering      year 1           1
# 997  2023-07-09  Female   19  Human Sciences       Year 2           0
# 998  2023-07-09  Female   24  Human Sciences       Year 2           1
# 999  2023-07-09  Female   20  Human Sciences       Year 2           1
#
#      Anxiety  PanicAttack  SpecialistTreatment  SymptomFrequency_Last7Days  \
# 0          0            0                    0                           5
# 1          1            0                    0                           0
# 2          0            1                    0                           3
# 3          0            0                    0                           3
# 4          1            0                    0                           0
# ..       ...          ...                  ...                         ...
# 995        1            0                    0                           6
# 996        0            0                    0                           3
# 997        0            1                    0                           1
# 998        0            1                    0                           5
# 999        0            0                    0                           0
#
#      HasMentalHealthSupport  SleepQuality  StudyStressLevel  \
# 0                         0             4                 5
# 1                         0             4                 4
# 2                         0             1                 2
# 3                         0             5                 1
# 4                         0             2                 4
# ..                      ...           ...               ...
# 995                       0             1                 3
# 996                       0             4                 1
# 997                       0             5                 4
# 998                       0             5                 4
# 999                       0             2                 5
#
#      StudyHoursPerWeek  AcademicEngagement  CGPA
# 0                    8                   2  2.38
# 1                   13                   5  4.00
# 2                   13                   1  3.68
# 3                   19                   2  4.00
# 4                    3                   2  2.00
# ..                 ...                 ...   ...
# 995                  7                   1  2.31
# 996                 12                   2  3.72
# 997                  3                   1  2.00
# 998                 13                   3  3.89
# 999                  8                   1  2.46
#
# [1000 rows x 16 columns]

# %%
#Checking for missing values
df.isnull().sum()
# Out:
# Timestamp                     0
# Gender                        0
# Age                           0
# Course                        0
# YearOfStudy                   0
# Depression                    0
# Anxiety                       0
# PanicAttack                   0
# SpecialistTreatment           0
# SymptomFrequency_Last7Days    0
# HasMentalHealthSupport        0
# SleepQuality                  0
# StudyStressLevel              0
# StudyHoursPerWeek             0
# AcademicEngagement            0
# CGPA                          0
# dtype: int64

# %% [markdown]
# # Checking for Duplicated Values

# %%
# Check for duplicate rows in the DataFrame
duplicate_rows = df[df.duplicated()]

print(f"Number of duplicate rows: {duplicate_rows.shape[0]}")
print()
if duplicate_rows.shape[0] > 0:
    print("Duplicate Rows:")
    print(duplicate_rows)
else:
    print("No duplicate rows found.")
# Out:
# Number of duplicate rows: 0
#
# No duplicate rows found.

# %% [markdown]
# # Drop Unnecessary Column

# %%
#To remove columns Timestamp and Course in the Dataframe
df = df.drop(["Timestamp", "Course"], axis=1)

# %%
#check dataframe again
df
# Out:
#      Gender  Age YearOfStudy  Depression  Anxiety  PanicAttack  \
# 0    Female   24      Year 3           1        0            0
# 1    Female   18      Year 3           0        1            0
# 2    Female   25      Year 3           0        0            1
# 3    Female   18      year 4           0        0            0
# 4    Female   20      year 4           1        1            0
# ..      ...  ...         ...         ...      ...          ...
# 995  Female   20      year 1           0        1            0
# 996  Female   23      year 1           1        0            0
# 997  Female   19      Year 2           0        0            1
# 998  Female   24      Year 2           1        0            1
# 999  Female   20      Year 2           1        0            0
#
#      SpecialistTreatment  SymptomFrequency_Last7Days  HasMentalHealthSupport  \
# 0                      0                           5                       0
# 1                      0                           0                       0
# 2                      0                           3                       0
# 3                      0                           3                       0
# 4                      0                           0                       0
# ..                   ...                         ...                     ...
# 995                    0                           6                       0
# 996                    0                           3                       0
# 997                    0                           1                       0
# 998                    0                           5                       0
# 999                    0                           0                       0
#
#      SleepQuality  StudyStressLevel  StudyHoursPerWeek  AcademicEngagement  \
# 0               4                 5                  8                   2
# 1               4                 4                 13                   5
# 2               1                 2                 13                   1
# 3               5                 1                 19                   2
# 4               2                 4                  3                   2
# ..            ...               ...                ...                 ...
# 995             1                 3                  7                   1
# 996             4                 1                 12                   2
# 997             5                 4                  3                   1
# 998             5                 4                 13                   3
# 999             2                 5                  8                   1
#
#      CGPA
# 0    2.38
# 1    4.00
# 2    3.68
# 3    4.00
# 4    2.00
# ..    ...
# 995  2.31
# 996  3.72
# 997  2.00
# 998  3.89
# 999  2.46
#
# [1000 rows x 14 columns]

# %% [markdown]
# # Convert Categorical Data to Numerical

# %%
#Import a tools from scikit-learn ML library module 
from sklearn.preprocessing import LabelEncoder

# Creates a LabelEncoder object and stores it in variable 'le'
le = LabelEncoder()

# Assuming 'Gender' is the column with 'Male' and 'Female'
#fit = learns the unique values (e.g. Male, Female), transform = converts them to numbers
df['Gender'] = le.fit_transform(df['Gender'])

# To show the label encoding mapping (male -> 0, female -> 1)
# will overwrites the column with the new number version
encoding_map = dict(zip(le.classes_, le.transform(le.classes_)))
print("Label Encoding Map:", encoding_map)
print()

#To verify result
print(df[['Gender']])
# Out:
# Label Encoding Map: {'Female': np.int64(0), 'Male': np.int64(1)}
#
#      Gender
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 995       0
# 996       0
# 997       0
# 998       0
# 999       0
#
# [1000 rows x 1 columns]

# %%
#Remove 'year' regardless of case
df['YearOfStudy'] = df['YearOfStudy'].str.replace(r'(?i)year', '', regex=True)

#Convert the result to integers
df['YearOfStudy'] = pd.to_numeric(df['YearOfStudy'], errors='coerce')

#Verify the result
print(df[['YearOfStudy']])
# Out:
#      YearOfStudy
# 0              3
# 1              3
# 2              3
# 3              4
# 4              4
# ..           ...
# 995            1
# 996            1
# 997            2
# 998            2
# 999            2
#
# [1000 rows x 1 columns]

# %%
df
# Out:
#      Gender  Age  YearOfStudy  Depression  Anxiety  PanicAttack  \
# 0         0   24            3           1        0            0
# 1         0   18            3           0        1            0
# 2         0   25            3           0        0            1
# 3         0   18            4           0        0            0
# 4         0   20            4           1        1            0
# ..      ...  ...          ...         ...      ...          ...
# 995       0   20            1           0        1            0
# 996       0   23            1           1        0            0
# 997       0   19            2           0        0            1
# 998       0   24            2           1        0            1
# 999       0   20            2           1        0            0
#
#      SpecialistTreatment  SymptomFrequency_Last7Days  HasMentalHealthSupport  \
# 0                      0                           5                       0
# 1                      0                           0                       0
# 2                      0                           3                       0
# 3                      0                           3                       0
# 4                      0                           0                       0
# ..                   ...                         ...                     ...
# 995                    0                           6                       0
# 996                    0                           3                       0
# 997                    0                           1                       0
# 998                    0                           5                       0
# 999                    0                           0                       0
#
#      SleepQuality  StudyStressLevel  StudyHoursPerWeek  AcademicEngagement  \
# 0               4                 5                  8                   2
# 1               4                 4                 13                   5
# 2               1                 2                 13                   1
# 3               5                 1                 19                   2
# 4               2                 4                  3                   2
# ..            ...               ...                ...                 ...
# 995             1                 3                  7                   1
# 996             4                 1                 12                   2
# 997             5                 4                  3                   1
# 998             5                 4                 13                   3
# 999             2                 5                  8                   1
#
#      CGPA
# 0    2.38
# 1    4.00
# 2    3.68
# 3    4.00
# 4    2.00
# ..    ...
# 995  2.31
# 996  3.72
# 997  2.00
# 998  3.89
# 999  2.46
#
# [1000 rows x 14 columns]

# %% [markdown]
# # Verify all features to be Numerical

# %%
df.dtypes
# Out:
# Gender                          int64
# Age                             int64
# YearOfStudy                     int64
# Depression                      int64
# Anxiety                         int64
# PanicAttack                     int64
# SpecialistTreatment             int64
# SymptomFrequency_Last7Days      int64
# HasMentalHealthSupport          int64
# SleepQuality                    int64
# StudyStressLevel                int64
# StudyHoursPerWeek               int64
# AcademicEngagement              int64
# CGPA                          float64
# dtype: object

# %%
df
# Out:
#      Gender  Age  YearOfStudy  Depression  Anxiety  PanicAttack  \
# 0         0   24            3           1        0            0
# 1         0   18            3           0        1            0
# 2         0   25            3           0        0            1
# 3         0   18            4           0        0            0
# 4         0   20            4           1        1            0
# ..      ...  ...          ...         ...      ...          ...
# 995       0   20            1           0        1            0
# 996       0   23            1           1        0            0
# 997       0   19            2           0        0            1
# 998       0   24            2           1        0            1
# 999       0   20            2           1        0            0
#
#      SpecialistTreatment  SymptomFrequency_Last7Days  HasMentalHealthSupport  \
# 0                      0                           5                       0
# 1                      0                           0                       0
# 2                      0                           3                       0
# 3                      0                           3                       0
# 4                      0                           0                       0
# ..                   ...                         ...                     ...
# 995                    0                           6                       0
# 996                    0                           3                       0
# 997                    0                           1                       0
# 998                    0                           5                       0
# 999                    0                           0                       0
#
#      SleepQuality  StudyStressLevel  StudyHoursPerWeek  AcademicEngagement  \
# 0               4                 5                  8                   2
# 1               4                 4                 13                   5
# 2               1                 2                 13                   1
# 3               5                 1                 19                   2
# 4               2                 4                  3                   2
# ..            ...               ...                ...                 ...
# 995             1                 3                  7                   1
# 996             4                 1                 12                   2
# 997             5                 4                  3                   1
# 998             5                 4                 13                   3
# 999             2                 5                  8                   1
#
#      CGPA
# 0    2.38
# 1    4.00
# 2    3.68
# 3    4.00
# 4    2.00
# ..    ...
# 995  2.31
# 996  3.72
# 997  2.00
# 998  3.89
# 999  2.46
#
# [1000 rows x 14 columns]

# %% [markdown]
# # Final Cleaned Data

# %%
#Reset index and drop the old index
df = df.reset_index(drop=True)

df
# Out:
#      Gender  Age  YearOfStudy  Depression  Anxiety  PanicAttack  \
# 0         0   24            3           1        0            0
# 1         0   18            3           0        1            0
# 2         0   25            3           0        0            1
# 3         0   18            4           0        0            0
# 4         0   20            4           1        1            0
# ..      ...  ...          ...         ...      ...          ...
# 995       0   20            1           0        1            0
# 996       0   23            1           1        0            0
# 997       0   19            2           0        0            1
# 998       0   24            2           1        0            1
# 999       0   20            2           1        0            0
#
#      SpecialistTreatment  SymptomFrequency_Last7Days  HasMentalHealthSupport  \
# 0                      0                           5                       0
# 1                      0                           0                       0
# 2                      0                           3                       0
# 3                      0                           3                       0
# 4                      0                           0                       0
# ..                   ...                         ...                     ...
# 995                    0                           6                       0
# 996                    0                           3                       0
# 997                    0                           1                       0
# 998                    0                           5                       0
# 999                    0                           0                       0
#
#      SleepQuality  StudyStressLevel  StudyHoursPerWeek  AcademicEngagement  \
# 0               4                 5                  8                   2
# 1               4                 4                 13                   5
# 2               1                 2                 13                   1
# 3               5                 1                 19                   2
# 4               2                 4                  3                   2
# ..            ...               ...                ...                 ...
# 995             1                 3                  7                   1
# 996             4                 1                 12                   2
# 997             5                 4                  3                   1
# 998             5                 4                 13                   3
# 999             2                 5                  8                   1
#
#      CGPA
# 0    2.38
# 1    4.00
# 2    3.68
# 3    4.00
# 4    2.00
# ..    ...
# 995  2.31
# 996  3.72
# 997  2.00
# 998  3.89
# 999  2.46
#
# [1000 rows x 14 columns]

# %% [markdown]
# # Descriptive Statistical Analysis

# %%
#Describe Data
df.describe()
# Out:
#             Gender          Age  YearOfStudy   Depression      Anxiety  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.240000    21.402000     1.976000     0.483000     0.474000
# std       0.427297     2.373611     0.973844     0.499961     0.499573
# min       0.000000    18.000000     1.000000     0.000000     0.000000
# 25%       0.000000    19.000000     1.000000     0.000000     0.000000
# 50%       0.000000    21.000000     2.000000     0.000000     0.000000
# 75%       0.000000    24.000000     3.000000     1.000000     1.000000
# max       1.000000    25.000000     4.000000     1.000000     1.000000
#
#        PanicAttack  SpecialistTreatment  SymptomFrequency_Last7Days  \
# count  1000.000000          1000.000000                   1000.0000
# mean      0.458000             0.067000                      3.4980
# std       0.498482             0.250147                      2.3081
# min       0.000000             0.000000                      0.0000
# 25%       0.000000             0.000000                      1.7500
# 50%       0.000000             0.000000                      3.0000
# 75%       1.000000             0.000000                      6.0000
# max       1.000000             1.000000                      7.0000
#
#        HasMentalHealthSupport  SleepQuality  StudyStressLevel  \
# count             1000.000000   1000.000000       1000.000000
# mean                 0.067000      2.983000          3.045000
# std                  0.250147      1.417999          1.417386
# min                  0.000000      1.000000          1.000000
# 25%                  0.000000      2.000000          2.000000
# 50%                  0.000000      3.000000          3.000000
# 75%                  0.000000      4.000000          4.000000
# max                  1.000000      5.000000          5.000000
#
#        StudyHoursPerWeek  AcademicEngagement         CGPA
# count        1000.000000         1000.000000  1000.000000
# mean            9.746000            3.055000     3.122530
# std             5.651497            1.422673     0.810961
# min             1.000000            1.000000     2.000000
# 25%             5.000000            2.000000     2.250000
# 50%             9.000000            3.000000     3.250000
# 75%            15.000000            4.000000     4.000000
# max            19.000000            5.000000     4.000000

# %% [markdown]
# # Measures of Central Tendency

# %%
#Select Column
columns_to_analysis = df.columns[0:13]

#Calculate mean, median, and mode for each column
mean_values = df[columns_to_analysis].mean()
median_values = df[columns_to_analysis].median()
mode_values = df[columns_to_analysis].mode().iloc[0]

#Display the results
print("Mean values for features:")
print(mean_values)
print("\nMedian values for features:")
print(median_values)
print("\nMode values for features:")
print(mode_values)
# Out:
# Mean values for features:
# Gender                         0.240
# Age                           21.402
# YearOfStudy                    1.976
# Depression                     0.483
# Anxiety                        0.474
# PanicAttack                    0.458
# SpecialistTreatment            0.067
# SymptomFrequency_Last7Days     3.498
# HasMentalHealthSupport         0.067
# SleepQuality                   2.983
# StudyStressLevel               3.045
# StudyHoursPerWeek              9.746
# AcademicEngagement             3.055
# dtype: float64
#
# Median values for features:
# Gender                         0.0
# Age                           21.0
# YearOfStudy                    2.0
# Depression                     0.0
# Anxiety                        0.0
# PanicAttack                    0.0
# SpecialistTreatment            0.0
# SymptomFrequency_Last7Days     3.0
# HasMentalHealthSupport         0.0
# SleepQuality                   3.0
# StudyStressLevel               3.0
# StudyHoursPerWeek              9.0
# AcademicEngagement             3.0
# dtype: float64
#
# Mode values for features:
# Gender                         0
# Age                           18
# YearOfStudy                    1
# Depression                     0
# Anxiety                        0
# PanicAttack                    0
# SpecialistTreatment            0
# SymptomFrequency_Last7Days     3
# HasMentalHealthSupport         0
# SleepQuality                   3
# StudyStressLevel               5
# StudyHoursPerWeek              1
# AcademicEngagement             4
# Name: 0, dtype: int64

# %% [markdown]
# # Measures of Variability

# %%
#Select column
columns_of_variable = df.columns[0:13]

#Calculate standard deviation, variance, and range for each numerical column
std_values = df[columns_of_variable].std()
variance_values = df[columns_of_variable].var()
range_values = df[columns_of_variable].max() - df[columns_of_variable].min()

#Display the results
print("Standard Deviation values for numerical features:")
print(std_values)
print("\nVariance values for numerical features:")
print(variance_values)
print("\nRange values for numerical features:")
print(range_values)
# Out:
# Standard Deviation values for numerical features:
# Gender                        0.427297
# Age                           2.373611
# YearOfStudy                   0.973844
# Depression                    0.499961
# Anxiety                       0.499573
# PanicAttack                   0.498482
# SpecialistTreatment           0.250147
# SymptomFrequency_Last7Days    2.308100
# HasMentalHealthSupport        0.250147
# SleepQuality                  1.417999
# StudyStressLevel              1.417386
# StudyHoursPerWeek             5.651497
# AcademicEngagement            1.422673
# dtype: float64
#
# Variance values for numerical features:
# Gender                         0.182583
# Age                            5.634030
# YearOfStudy                    0.948372
# Depression                     0.249961
# Anxiety                        0.249574
# PanicAttack                    0.248484
# SpecialistTreatment            0.062574
# SymptomFrequency_Last7Days     5.327323
# HasMentalHealthSupport         0.062574
# SleepQuality                   2.010722
# StudyStressLevel               2.008984
# StudyHoursPerWeek             31.939423
# AcademicEngagement             2.023999
# dtype: float64
#
# Range values for numerical features:
# Gender                         1
# Age                            7
# YearOfStudy                    3
# Depression                     1
# Anxiety                        1
# PanicAttack                    1
# SpecialistTreatment            1
# SymptomFrequency_Last7Days     7
# HasMentalHealthSupport         1
# SleepQuality                   4
# StudyStressLevel               4
# StudyHoursPerWeek             18
# AcademicEngagement             4
# dtype: int64

# %% [markdown]
# # Distribution of Features

# %%
#Loads matplotlib (for plotting) and seaborn (for statistical charts)
import matplotlib.pyplot as plt
import seaborn as sns

#Drop the target column
df_features = df.drop(columns=[df.columns[13]]) 

#Visualize the distribution of all features except the target
def plot_distributions(df, cols_per_row=3):   #Define the plotting function
    num_cols = len(df.columns)   #total number of columns/features to plot
    num_rows = (num_cols // cols_per_row) + int(num_cols % cols_per_row > 0)  #calculates how many rows are needed and adds an extra row

    plt.figure(figsize=(cols_per_row * 6, num_rows * 5))  #Set figure size
    for i, column in enumerate(df.columns, 1):   #Loops through every column, starting count at 1
        plt.subplot(num_rows, cols_per_row, i)   #positions each chart in the correct grid slot
        sns.histplot(df[column], kde=True, bins=30, color='blue', edgecolor='black')   #Draw the histogram
        plt.title(f"Distribution of {column}", fontsize='14') #Increased title font size
        plt.xlabel(column, fontsize=12)  #Increase x-label font size
        plt.ylabel("Frequency", fontsize=12)  #Increase y-label font size
        plt.tight_layout()  #prevents charts from overlapping each other
    plt.show()  #renders and displays all the plots

#Call the function to plot distribution
plot_distributions(df_features, cols_per_row=3)

# %% [markdown]
# # Checking for Outliers

# %%
#Plot boxplots for numerical columns
plt.figure(figsize=(12, 8))  #Creates a blank canvas sized 12 inches wide × 8 inches tal
sns.boxplot(data=df)         #Draws a box plot
plt.xticks(rotation=90)      #Rotates the x-axis labels by 90°
plt.title('Box Plots for Numerical Features') #Adds title at the top of the chart
plt.show()

# %% [markdown]
# # Verify Outliers using IQR

# %%
#Loop through all columns except CGPA
for column in df.columns:
    if column != 'CGPA':
        #Calculate Q1, Q3, and IQR for each column
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1

        #Define the outlier threshold
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        #Check for outliers
        outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]

        #Print if no outliers are found for the column
        if outliers.empty:
            print(f"No outliers detected in {column}")
        else:
            print(f"Outliers detected in {column}:")
            print(outliers[[column]])
# Out:
# Outliers detected in Gender:
#      Gender
# 13        1
# 14        1
# 20        1
# 21        1
# 22        1
# ..      ...
# 952       1
# 977       1
# 978       1
# 991       1
# 992       1
#
# [240 rows x 1 columns]
# No outliers detected in Age
# No outliers detected in YearOfStudy
# No outliers detected in Depression
# No outliers detected in Anxiety
# No outliers detected in PanicAttack
# Outliers detected in SpecialistTreatment:
#      SpecialistTreatment
# 15                     1
# 136                    1
# 137                    1
# 151                    1
# 152                    1
# ..                   ...
# 944                    1
# 945                    1
# 946                    1
# 947                    1
# 948                    1
#
# [67 rows x 1 columns]
# No outliers detected in SymptomFrequency_Last7Days
# Outliers detected in HasMentalHealthSupport:
#      HasMentalHealthSupport
# 15                        1
# 136                       1
# 137                       1
# 151                       1
# 152                       1
# ..                      ...
# 944                       1
# 945                       1
# 946                       1
# 947                       1
# 948                       1
#
# [67 rows x 1 columns]
# No outliers detected in SleepQuality
# No outliers detected in StudyStressLevel
# No outliers detected in StudyHoursPerWeek
# No outliers detected in AcademicEngagement

# %% [markdown]
# # Correlation

# %%
#Correlation Matrix
correlation_matrix = df.corr("pearson")
correlation_matrix
# Out:
#                               Gender       Age  YearOfStudy  Depression  \
# Gender                      1.000000  0.009396    -0.051094   -0.041796
# Age                         0.009396  1.000000     0.022799   -0.011106
# YearOfStudy                -0.051094  0.022799     1.000000    0.044392
# Depression                 -0.041796 -0.011106     0.044392    1.000000
# Anxiety                     0.005815  0.039213    -0.019802    0.048325
# PanicAttack                -0.013723  0.024436     0.016480   -0.004876
# SpecialistTreatment        -0.000749  0.037201    -0.071466   -0.018897
# SymptomFrequency_Last7Days -0.051276 -0.016297     0.008440    0.029030
# HasMentalHealthSupport     -0.000749  0.037201    -0.071466   -0.018897
# SleepQuality                0.031522  0.023148     0.001879   -0.016646
# StudyStressLevel           -0.007933 -0.031565     0.014562   -0.001038
# StudyHoursPerWeek           0.012004 -0.032079    -0.038394   -0.015346
# AcademicEngagement          0.006257  0.001450     0.019739   -0.079605
# CGPA                        0.007808 -0.048808    -0.017389    0.054335
#
#                              Anxiety  PanicAttack  SpecialistTreatment  \
# Gender                      0.005815    -0.013723            -0.000749
# Age                         0.039213     0.024436             0.037201
# YearOfStudy                -0.019802     0.016480            -0.071466
# Depression                  0.048325    -0.004876            -0.018897
# Anxiety                     1.000000     0.027768             0.017959
# PanicAttack                 0.027768     1.000000            -0.037618
# SpecialistTreatment         0.017959    -0.037618             1.000000
# SymptomFrequency_Last7Days -0.053869    -0.032264             0.002833
# HasMentalHealthSupport      0.017959    -0.037618             1.000000
# SleepQuality               -0.019701    -0.001719             0.039901
# StudyStressLevel            0.036289     0.052973            -0.000042
# StudyHoursPerWeek          -0.008723     0.035650            -0.024770
# AcademicEngagement          0.074547    -0.003091             0.037452
# CGPA                        0.037039     0.070897            -0.015294
#
#                             SymptomFrequency_Last7Days  \
# Gender                                       -0.051276
# Age                                          -0.016297
# YearOfStudy                                   0.008440
# Depression                                    0.029030
# Anxiety                                      -0.053869
# PanicAttack                                  -0.032264
# SpecialistTreatment                           0.002833
# SymptomFrequency_Last7Days                    1.000000
# HasMentalHealthSupport                        0.002833
# SleepQuality                                  0.036538
# StudyStressLevel                             -0.050918
# StudyHoursPerWeek                             0.014848
# AcademicEngagement                           -0.015666
# CGPA                                          0.023156
#
#                             HasMentalHealthSupport  SleepQuality  \
# Gender                                   -0.000749      0.031522
# Age                                       0.037201      0.023148
# YearOfStudy                              -0.071466      0.001879
# Depression                               -0.018897     -0.016646
# Anxiety                                   0.017959     -0.019701
# PanicAttack                              -0.037618     -0.001719
# SpecialistTreatment                       1.000000      0.039901
# SymptomFrequency_Last7Days                0.002833      0.036538
# HasMentalHealthSupport                    1.000000      0.039901
# SleepQuality                              0.039901      1.000000
# StudyStressLevel                         -0.000042      0.004863
# StudyHoursPerWeek                        -0.024770      0.014700
# AcademicEngagement                        0.037452     -0.000032
# CGPA                                     -0.015294      0.047052
#
#                             StudyStressLevel  StudyHoursPerWeek  \
# Gender                             -0.007933           0.012004
# Age                                -0.031565          -0.032079
# YearOfStudy                         0.014562          -0.038394
# Depression                         -0.001038          -0.015346
# Anxiety                             0.036289          -0.008723
# PanicAttack                         0.052973           0.035650
# SpecialistTreatment                -0.000042          -0.024770
# SymptomFrequency_Last7Days         -0.050918           0.014848
# HasMentalHealthSupport             -0.000042          -0.024770
# SleepQuality                        0.004863           0.014700
# StudyStressLevel                    1.000000           0.013800
# StudyHoursPerWeek                   0.013800           1.000000
# AcademicEngagement                  0.036499           0.026639
# CGPA                                0.028195           0.932091
#
#                             AcademicEngagement      CGPA
# Gender                                0.006257  0.007808
# Age                                   0.001450 -0.048808
# YearOfStudy                           0.019739 -0.017389
# Depression                           -0.079605  0.054335
# Anxiety                               0.074547  0.037039
# PanicAttack                          -0.003091  0.070897
# SpecialistTreatment                   0.037452 -0.015294
# SymptomFrequency_Last7Days           -0.015666  0.023156
# HasMentalHealthSupport                0.037452 -0.015294
# SleepQuality                         -0.000032  0.047052
# StudyStressLevel                      0.036499  0.028195
# StudyHoursPerWeek                     0.026639  0.932091
# AcademicEngagement                    1.000000  0.152381
# CGPA                                  0.152381  1.000000

# %% [markdown]
# # Correlation by Ranking

# %%
#Assuming correlation_matrix is already calculated
correlation_with_success = correlation_matrix['CGPA']

#Sort the correlation values in descending order
correlation_ranked = correlation_with_success.sort_values(ascending=False)

#Print the ranked correlation values
print(correlation_ranked)
# Out:
# CGPA                          1.000000
# StudyHoursPerWeek             0.932091
# AcademicEngagement            0.152381
# PanicAttack                   0.070897
# Depression                    0.054335
# SleepQuality                  0.047052
# Anxiety                       0.037039
# StudyStressLevel              0.028195
# SymptomFrequency_Last7Days    0.023156
# Gender                        0.007808
# SpecialistTreatment          -0.015294
# HasMentalHealthSupport       -0.015294
# YearOfStudy                  -0.017389
# Age                          -0.048808
# Name: CGPA, dtype: float64

# %% [markdown]
# # Correlation Heatmap

# %%
#Compute the correlation matrix
correlation_matrix = df.corr()

#Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(12, 8))   #Adjust figure size
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

#Customize the plot
plt.title('Correlation Heatmap', fontsize=16)
plt.show()

# %% [markdown]
# # Correlation of All Features by Class (Target Label)

# %%
#Define features and target
features = df.columns[:13]
target = df.columns[13]

#Function to plot scatter plots for each feature against the target
def plot_scatter_features_vs_target(df, features, target, cols_per_row=4):
    num_features = len(features)
    num_rows = (num_features // cols_per_row) + int(num_features % cols_per_row > 0)

    plt.figure(figsize=(cols_per_row * 6, num_rows * 5))  #adjust figure size for better read
    for i, feature in enumerate(features,1):
        plt.subplot(num_rows, cols_per_row, i)
        plt.scatter(df[feature], df[target], alpha=0.7, c='blue', edgecolor='k')
        plt.title(f'{feature} vs {target}', fontsize=14)
        plt.xlabel(feature, fontsize=12)
        plt.ylabel(target, fontsize=12)
        plt.tight_layout()
    plt.show()

#Call the function to plot scatter plots
plot_scatter_features_vs_target(df, features, target, cols_per_row=4)

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import RandomForestRegressor

#Prepare data
X = df.drop(columns=['CGPA'])
y = df['CGPA']

#Train a random Forest Regressor model
rf = RandomForestRegressor()
rf.fit(X, y)

#Get feature importances
importances = rf.feature_importances_

#Create a DataFrame for feature importances
feature_importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

#Plot the feature importance
plt.figure(figsize=(10, 6))
sns.barplot(data=feature_importance_df, x='Importance', y='Feature')
plt.title('Feature Importance for Continuous Target Prediction')
plt.show()

# %% [markdown]
# # Relationship Between Attributes

# %%
#Pairplot to visualize relationship
sns.pairplot(df, diag_kind="kde")
plt.suptitle("Pairwise Relationship Between Attributes", y=1.02)
plt.show()

# %% [markdown]
# # Data Transformation

# %% [markdown]
# # Standardizer

# %%
from sklearn.preprocessing import StandardScaler

array = df.values

#Separate array into input and output components
X = array[:,0:13]
Y = array[:,13]
scaler = StandardScaler()
standardizedX = scaler.fit_transform(X)

#print(X[0:5,:])
print(standardizedX[0:5,:])
# Out:
# [[-0.56195149  1.09508246  1.05202913  1.03459817 -0.9492843  -0.91924885
#   -0.26797642  0.65107746 -0.26797642  0.71756661  1.37998949 -0.30909926
#   -0.7419328 ]
#  [-0.56195149 -1.43397634  1.05202913 -0.96655883  1.05342519 -0.91924885
#   -0.26797642 -1.51629092 -0.26797642  0.71756661  0.67411252  0.57606471
#    1.36782871]
#  [-0.56195149  1.51659226  1.05202913 -0.96655883 -0.9492843   1.08784471
#   -0.26797642 -0.21586989 -0.26797642 -1.39914906 -0.73764144  0.57606471
#   -1.44518663]
#  [-0.56195149 -1.43397634  2.07940133 -0.96655883 -0.9492843  -0.91924885
#   -0.26797642 -0.21586989 -0.26797642  1.42313851 -1.44351842  1.63826146
#   -0.7419328 ]
#  [-0.56195149 -0.59095674  2.07940133  1.03459817  1.05342519 -0.91924885
#   -0.26797642 -1.51629092 -0.26797642 -0.69357717  0.67411252 -1.19426322
#   -0.7419328 ]]

# %% [markdown]
# # Log Scaling

# %%
import numpy as np

array = df.values

#Separate array into input and output components
X = array[:, 0:13]
Y = array[:, 13]

#Apply log scaling (adding 1 to avoid log(0))
log_scaled_X = np.log1p(X)

#Print the log-scaled values for the first 5 rows
print(log_scaled_X[0:5, :])
# Out:
# [[0.         3.21887582 1.38629436 0.69314718 0.         0.
#   0.         1.79175947 0.         1.60943791 1.79175947 2.19722458
#   1.09861229]
#  [0.         2.94443898 1.38629436 0.         0.69314718 0.
#   0.         0.         0.         1.60943791 1.60943791 2.63905733
#   1.79175947]
#  [0.         3.25809654 1.38629436 0.         0.         0.69314718
#   0.         1.38629436 0.         0.69314718 1.09861229 2.63905733
#   0.69314718]
#  [0.         2.94443898 1.60943791 0.         0.         0.
#   0.         1.38629436 0.         1.79175947 0.69314718 2.99573227
#   1.09861229]
#  [0.         3.04452244 1.60943791 0.69314718 0.69314718 0.
#   0.         0.         0.         1.09861229 1.60943791 1.38629436
#   1.09861229]]

# %% [markdown]
# # Min-Max Scaler

# %%
from sklearn.preprocessing import MinMaxScaler

array = df.values

#Separate array into input and output components
X = array[:,0:13]
Y = array[:,13]
scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(X)

#print(X[0:5,:])
print(rescaledX[0:5,:])
# Out:
# [[0.         0.85714286 0.66666667 1.         0.         0.
#   0.         0.71428571 0.         0.75       1.         0.38888889
#   0.25      ]
#  [0.         0.         0.66666667 0.         1.         0.
#   0.         0.         0.         0.75       0.75       0.66666667
#   1.        ]
#  [0.         1.         0.66666667 0.         0.         1.
#   0.         0.42857143 0.         0.         0.25       0.66666667
#   0.        ]
#  [0.         0.         1.         0.         0.         0.
#   0.         0.42857143 0.         1.         0.         1.
#   0.25      ]
#  [0.         0.28571429 1.         1.         1.         0.
#   0.         0.         0.         0.25       0.75       0.11111111
#   0.25      ]]

# %%
#Verify total rows and columns are matched

#Print the dimensions of rescaledX
print("Total Rows in rescaledX:", rescaledX.shape[0])
print("Total Columns in rescaledX:", rescaledX.shape[1])

#Compare with the first 13 columns of df
df_subset = df.iloc[:, :13]    #Select the first 13 columns
print("Total Rows in df (first 13 columns):", df_subset.shape[0])
print("Total Columns in df (first 13 columns):", df_subset.shape[1])

#Check if the totals match
if rescaledX.shape == df_subset.shape:
    print("\nThe total rows and column match!")
else:
    print("\nThe totals do not match.")
print()
rescaledX
# Out:
# Total Rows in rescaledX: 1000
# Total Columns in rescaledX: 13
# Total Rows in df (first 13 columns): 1000
# Total Columns in df (first 13 columns): 13
#
# The total rows and column match!
# array([[0.        , 0.85714286, 0.66666667, ..., 1.        , 0.38888889,
#         0.25      ],
#        [0.        , 0.        , 0.66666667, ..., 0.75      , 0.66666667,
#         1.        ],
#        [0.        , 1.        , 0.66666667, ..., 0.25      , 0.66666667,
#         0.        ],
#        ...,
#        [0.        , 0.14285714, 0.33333333, ..., 0.75      , 0.11111111,
#         0.        ],
#        [0.        , 0.85714286, 0.33333333, ..., 0.75      , 0.66666667,
#         0.5       ],
#        [0.        , 0.28571429, 0.33333333, ..., 1.        , 0.38888889,
#         0.        ]], shape=(1000, 13))

# %%
print(len(Y))
print()
Y
# Out:
# 1000
# array([2.38, 4.  , 3.68, 4.  , 2.  , 4.  , 2.  , 2.72, 2.3 , 4.  , 4.  ,
#        2.  , 4.  , 2.  , 2.84, 3.28, 4.  , 2.12, 2.  , 4.  , 2.59, 4.  ,
#        3.98, 4.  , 3.51, 2.  , 2.  , 3.12, 4.  , 2.  , 2.89, 2.  , 2.  ,
#        2.  , 4.  , 2.  , 4.  , 2.  , 4.  , 4.  , 3.38, 3.61, 3.77, 3.47,
#        2.58, 3.36, 2.89, 4.  , 3.5 , 2.38, 4.  , 3.39, 4.  , 3.95, 4.  ,
#        2.  , 3.25, 3.12, 2.  , 3.25, 2.  , 2.  , 4.  , 4.  , 2.75, 4.  ,
#        2.77, 3.3 , 3.96, 2.  , 4.  , 2.  , 2.9 , 4.  , 2.43, 2.  , 3.77,
#        2.  , 2.  , 2.42, 4.  , 2.28, 4.  , 2.  , 2.38, 2.83, 4.  , 4.  ,
#        2.21, 3.86, 3.99, 2.  , 4.  , 4.  , 2.34, 3.6 , 3.69, 2.  , 3.64,
#        4.  , 4.  , 4.  , 2.  , 3.83, 2.31, 3.72, 2.  , 3.89, 2.46])

# %% [markdown]
# # Splitting to Train and Test Data

# %% [markdown]
# # Use Non-Transformed Data for Training and Test

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

array = df.values

#Extract X(features) and y(target)
#X = rescaledX
#X = log_scaled_X
X = array[:,0:13]
#X = standardizedX

y = Y

#Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print("Total training data of X:", len(X_train))
print("Total test data of X:", len(X_test))
print()
print("Total training data of Y:", len(y_train))
print("Total test data of Y:", len(y_test))
# Out:
# Total training data of X: 700
# Total test data of X: 300
#
# Total training data of Y: 700
# Total test data of Y: 300

# %%
print(len(X_train))
print()
X_train
# Out:
# 700
# array([[ 0., 19.,  2., ...,  1., 12.,  1.],
#        [ 0., 18.,  2., ...,  3.,  5.,  4.],
#        [ 0., 22.,  3., ...,  2., 13.,  2.],
#        ...,
#        [ 0., 24.,  1., ...,  5., 19.,  3.],
#        [ 0., 24.,  1., ...,  1., 18.,  4.],
#        [ 1., 20.,  3., ...,  4.,  8.,  4.]], shape=(700, 13))

# %% [markdown]
# # Checking for Data Imbalance

# %% [markdown]
# # Histogram of CGPA Distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Plot the distribution of CGPA
plt.figure(figsize=(10, 6))
sns.histplot(df['CGPA'], kde=True, bins=30, color='blue')
plt.title('Distribution of CGPA')
plt.xlabel('CGPA')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Measurement of Skewness

# %%
#Summary of statistics
print(df['CGPA'].describe())

#Check skewness
from scipy.stats import skew
print(f"Skewness of CGPA: {skew(df['CGPA'])}")
# Out:
# count    1000.000000
# mean        3.122530
# std         0.810961
# min         2.000000
# 25%         2.250000
# 50%         3.250000
# 75%         4.000000
# max         4.000000
# Name: CGPA, dtype: float64
# Skewness of CGPA: -0.21613441185513024

# %% [markdown]
# # Checking for Outliers

# %%
#Boxplot to detect outliers
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['CGPA'])
plt.title('Boxplot of CGPA')
plt.xlabel('CGPA')
plt.show()

# %% [markdown]
# # Density Plot

# %%
#Density plot for CGPA
plt.figure(figsize=(10, 6))
sns.kdeplot(df['CGPA'], fill=True, color='blue')
plt.title('Density Plot of CGPA')
plt.xlabel('CGPA')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# # Train, Test and Evaluate Models

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import learning_curve
import xgboost as xgb

#Initialize the models
models = {
    'Linear Regression': LinearRegression(),
    'Random Forest Regressor': RandomForestRegressor(),
    'XGBoost': xgb.XGBRegressor(),
    'Support Vector Regressor (SVR)': SVR(),
    'K-Nearest Neighbors (KNN)': KNeighborsRegressor(),
    'MLP Regressor': MLPRegressor(max_iter=1000)
}

#Prepare the results dictionary
results = {}

for model_name, model in models.items():
    #train the model
    model.fit(X_train, y_train)

    #Make predictions
    y_pred = model.predict(X_test)

    #Calculate evaluation metrics
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    #Store results
    results[model_name] = {
        'MAE': mae,
        'MSE': mse,
        'RMSE': rmse,
        'R²': r2
    }

    #Plot learning curve (for models that support it)
    if model_name != 'MLP Regressor':
        train_sizes, train_scores, test_scores = learning_curve(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')

        plt.figure(figsize=(10, 6))
        plt.plot(train_sizes, -train_scores.mean(axis=1), label="Training Error")
        plt.plot(train_sizes, -test_scores.mean(axis=1), label="Validation Error")
        plt.title(f'Learning Curve for {model_name}')
        plt.xlabel('Training Set Size')
        plt.ylabel('Negative MSE')
        plt.legend()
        plt.grid(True)
        plt.show()

    #Plot Loss Curve for MLP Regressor
    if model_name == 'MLP Regressor':
        plt.plot(model.loss_curve_)
        plt.title(f'Loss Curve for {model_name}')
        plt.xlabel('Iterations')
        plt.ylabel('Loss')
        plt.grid(True)
        plt.show()

#Output the evaluation metrics
for model_name, metrics in results.items():
    print(f"Results for {model_name}:")
    print(f"MAE: {metrics['MAE']:.4f}")
    print(f"MSE: {metrics['MSE']:.4f}")
    print(f"RMSE: {metrics['RMSE']:.4f}")
    print(f"R²: {metrics['R²']:.4f}\n")
# Out:
# Results for Linear Regression:
# MAE: 0.2087
# MSE: 0.0628
# RMSE: 0.2506
# R²: 0.9065
#
# Results for Random Forest Regressor:
# MAE: 0.1268
# MSE: 0.0393
# RMSE: 0.1982
# R²: 0.9415
#
# Results for XGBoost:
# MAE: 0.1427
# MSE: 0.0496
# RMSE: 0.2227
# R²: 0.9261
#
# Results for Support Vector Regressor (SVR):
# MAE: 0.1468
# MSE: 0.0387
# RMSE: 0.1967
# R²: 0.9424
#
# Results for K-Nearest Neighbors (KNN):
# MAE: 0.1396
# MSE: 0.0500
# RMSE: 0.2236
# R²: 0.9255
#
# Results for MLP Regressor:
# MAE: 0.1898
# MSE: 0.0591
# RMSE: 0.2430
# R²: 0.9120

# %% [markdown]
# # Comparison of Prediction Output for Each Model

# %%
#Create a dictionary to store predictions for each model
test_predictions = {}

#Loop through each model, make predictions, and store them
for model_name, model in models.items():
    y_pred = model.predict(X_test)   #Predict on the set
    test_predictions[model_name] = y_pred

#Convert the predictions dictionary into a DataFrame for better readability
predictions_df = pd.DataFrame(test_predictions)

#Add the actual values for comparison
predictions_df['Actual'] = y_test

#Display the predictions
predictions_df
# Out:
#      Linear Regression  Random Forest Regressor   XGBoost  \
# 0             3.189774                   3.6789  3.524912
# 1             4.189629                   3.9968  4.042435
# 2             2.613944                   2.3747  2.359975
# 3             2.327661                   2.0318  1.939151
# 4             4.215234                   3.9990  3.995707
# 5             1.972851                   2.0121  1.879734
# 6             2.110838                   2.0547  2.030132
# 7             3.142050                   3.5484  3.475211
# 8             4.357621                   3.9997  3.991923
# 9             3.058533                   2.9921  2.890861
# 10            2.823875                   2.9413  3.068056
# 11            3.369895                   3.5467  3.664019
# 12            2.489171                   2.4005  2.352767
# 13            3.744768                   3.9828  3.953584
# 14            4.354504                   3.9959  4.031747
# 15            2.439488                   2.2445  2.245904
# 16            3.185839                   3.5460  3.486207
# 17            3.893468                   3.9882  3.985843
# 18            2.090297                   2.0235  2.051079
# 19            2.304323                   2.0870  1.974145
